# %% [markdown]
# <a href="https://colab.research.google.com/github/nbilasals/sentiment-qris/blob/main/data_join_20192020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Juni 2019-Agustus 2020
import pandas as pd
import os

# Path ke folder CSV files
folder_path = "/content/drive/MyDrive/menyala 🔥🔥/dataset/older"

# List semua files di folder
all_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.csv')]

# List buat nyimpen data dari masing-masing CSV
dataframes = []

# Baca masing-masing CSV dan simpan ke list dataframes
for file in all_files:
    try:
        df = pd.read_csv(file)
        if df.empty:
            print(f"Skipping empty file: {file}")
            continue
        dataframes.append(df)
    except pd.errors.EmptyDataError:
        print(f"Skipping empty file: {file}")
        continue

# Gabungin semua dataframes jadi satu
merged_df = pd.concat(dataframes, ignore_index=True)
# Out:
# Skipping empty file: /content/drive/MyDrive/menyala 🔥🔥/dataset/older/transaksi_qris_juli_2019.csv
# Skipping empty file: /content/drive/MyDrive/menyala 🔥🔥/dataset/older/transaksi_qris_agus_20.old.csv

# %%
merged_df
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0     1164390355011350528  Thu Aug 22 04:14:28 +0000 2019               0
# 1     1166293789989715969  Tue Aug 27 10:18:02 +0000 2019               0
# 2     1162742768369692679  Sat Aug 17 15:07:33 +0000 2019               3
# 3     1162800035278589956  Sat Aug 17 18:55:06 +0000 2019               0
# 4     1164376717932105734  Thu Aug 22 03:20:17 +0000 2019               7
# ...                   ...                             ...             ...
# 1176  1171687191107399681  Wed Sep 11 07:29:29 +0000 2019               0
# 1177  1172513236882620416  Fri Sep 13 14:21:15 +0000 2019               0
# 1178  1174319336862801920  Thu Sep 19 02:50:18 +0000 2019               0
# 1179  1172737815370592258  Sat Sep 14 05:04:18 +0000 2019               1
# 1180  1172454349106077697  Fri Sep 13 10:17:56 +0000 2019               4
#
#                                               full_text               id_str  \
# ...

# %%
# Pastikan 'created_at' kolom diubah jadi tipe datetime
merged_df['created_at'] = pd.to_datetime(merged_df['created_at'])

# Ambil kolom 'created_at' dan 'full_text'
selected_columns_df = merged_df[['created_at', 'full_text']]
# Rename
selected_columns_df.rename(columns={'full_text': 'Komentar'}, inplace=True)

# Drop baris dengan nilai NaN
selected_columns_df = selected_columns_df.dropna()

# Sort dataframe berdasarkan 'created_at'
sorted_df = selected_columns_df.sort_values(by='created_at')

# Tampilkan beberapa baris pertama untuk verifikasi
sorted_df
# Out:
# <ipython-input-26-761ad7741c85>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_columns_df.rename(columns={'full_text': 'Komentar'}, inplace=True)
#                    created_at  \
# 69  2019-06-01 02:42:10+00:00
# 102 2019-06-01 07:42:43+00:00
# 86  2019-06-01 09:20:40+00:00
# 90  2019-06-01 11:22:21+00:00
# 101 2019-06-01 12:27:55+00:00
# ..                        ...
# 345 2020-08-28 13:14:33+00:00
# 805 2020-08-28 13:14:33+00:00
# 798 2020-08-28 13:25:03+00:00
# 984 2020-08-28 13:25:03+00:00
# 847 2020-08-28 23:48:16+00:00
#
#                                               Komentar
# 69   ・・・ Ini Tujuan BI Luncurkan QR Code Standard I...
# 102  @iam_realjayson @Poshfelly @kingsleynovich @Af...
# 86   @bonario89 @iam_realjayson @Poshfelly @Realchu...
# ...

# %%
# Path to save the CSV file on Google Drive
save_path = '/content/drive/MyDrive/menyala 🔥🔥/dataset/all data/qris_juni_aug20.csv'

# Save the DataFrame to CSV
sorted_df.to_csv(save_path, index=False)

print("DataFrame saved to Google Drive successfully!")
# Out:
# DataFrame saved to Google Drive successfully!

# %%
qris ="/content/drive/MyDrive/menyala 🔥🔥/qris_bi.csv"
qris
# Out:
# '/content/drive/MyDrive/menyala 🔥🔥/komen_qris_try1.gsheet'
